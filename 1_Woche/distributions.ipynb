# %% [markdown]
# ## Verteilungen
# Statistische Verteilungen: Beispiele, Numpy Funktionen, Anwendungen
# *"Neues" Packet* scipy

# %%
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# Um die Verteilungsfunktionen zu berechnen nutzen wir ein weiteres python packet aus der scipy Bibliothek

# %%
import scipy, scipy.stats

# %% [markdown]
# Um die Normalverteilung zu plotten wollen wir die Wahrscheinlichkeitsdichtefunktion (probability density function, pdf) an verschiedenen Stellen auswerten und mit *pyplot* plotten.

# %% [markdown]
# Mit Hilfe von der scipy Funktion linespace erstelle ich mir eine Liste an Werten. Diese nutze ich als Werte auf der x-Achse, an denen ich die *pdf* auswerten will

# %%
x = scipy.linspace(-10,10,100)

# %% [markdown]
# Dann berechne ich die pdf an den in **x** gespeicherten Stellen wie folgt

# %%
y = scipy.stats.norm.pdf(x,0,1)

# %% [markdown]
# Und plotte die Werte

# %%
plt.plot(x, y)

# %% [markdown]
# Wenn ich Werte einer Zufallsvariablen die einer Bestimmten Verteilung folgt ziehen will, kann ich das einfach mit *numpy* machen:

# %%
pl = np.random.normal (0,1,1000)

# %%
pl = np.sort(pl)

# %%
y_pl = scipy.stats.norm.pdf (pl,0,1)

# %%
plt.plot (pl,y_pl)

# %%
plt.hist(pl, bins=100)
# Out:
# (array([ 1.,  0.,  0.,  1.,  1.,  1.,  0.,  0.,  2.,  1.,  1.,  0.,  3.,
#          0.,  4.,  1.,  3.,  1.,  5.,  7.,  4.,  3., 12.,  6.,  4.,  6.,
#         11.,  4.,  8.,  9., 22.,  7., 16., 11., 24., 17., 20., 16., 16.,
#         14., 13., 17., 22., 18., 19., 18., 23., 25., 26., 23., 23., 22.,
#         31., 23., 28., 24., 31., 18., 22., 15., 24., 19., 16., 13., 22.,
#         16.,  9., 15., 15., 10., 10.,  7., 10., 12., 12.,  5., 10., 11.,
#          7., 10.,  5.,  6.,  7.,  2.,  1.,  7.,  1.,  2.,  1.,  4.,  1.,
#          0.,  3.,  1.,  0.,  0.,  1.,  1.,  0.,  1.]),
#  array([-2.98900002, -2.92992777, -2.87085552, -2.81178326, -2.75271101,
#         -2.69363876, -2.6345665 , -2.57549425, -2.516422  , -2.45734975,
#         -2.39827749, -2.33920524, -2.28013299, -2.22106073, -2.16198848,
#         -2.10291623, -2.04384397, -1.98477172, -1.92569947, -1.86662722,
#         -1.80755496, -1.74848271, -1.68941046, -1.6303382 , -1.57126595,
# ...

# %%
#Binominale Verteilung

# %%
binominalx = scipy.linspace(0,100,1000)

# %%
binominalxrandom = bernoulli.rvs(p, size=1000)

# %%
binominaly = scipy.stats.bernoulli.pmf?

# %%
binominaly = scipy.stats.bernoulli.pmf()

# %%
plt.plot (binominalx,binominaly)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-91-f71cecc06c5b> in <module>()
# ----> 1 plt.plot (binominalx,binominaly)
#
# ~\Anaconda3\lib\site-packages\matplotlib\pyplot.py in plot(*args, **kwargs)
#    3356                       mplDeprecation)
#    3357     try:
# -> 3358         ret = ax.plot(*args, **kwargs)
#    3359     finally:
#    3360         ax._hold = washold
#
# ~\Anaconda3\lib\site-packages\matplotlib\__init__.py in inner(ax, *args, **kwargs)
#    1853                         "the Matplotlib list!)" % (label_namer, func.__name__),
#    1854                         RuntimeWarning, stacklevel=2)
# -> 1855             return func(ax, *args, **kwargs)
#    1856
#    1857         inner.__doc__ = _add_data_doc(inner.__doc__,
#
# ~\Anaconda3\lib\site-packages\matplotlib\axes\_axes.py in plot(self, *args, **kwargs)
# ...

# %%
from scipy.stats import bernoulli
fig, ax = plt.subplots(1, 1)
p = 0.3
x = np.arange(bernoulli.ppf(0.01, p),
              bernoulli.ppf(0.99, p))
ax.plot(x, bernoulli.pmf(x, p), 'bo', ms=8, label='bernoulli pmf')
ax.vlines(x, 0, bernoulli.pmf(x, p), colors='b', lw=5, alpha=0.5)
rv = bernoulli(p)
ax.vlines(x, 0, rv.pmf(x), colors='k', linestyles='-', lw=1,
        label='frozen pmf')
ax.legend(loc='best', frameon=False)
plt.show()

# %%
np.arange(bernoulli.ppf(0.01, p),
              bernoulli.ppf(0.99, p))
# Out:
# array([0.])

# %%
mean, var, skew, kurt = bernoulli.stats(p, moments='mvsk')
mean, var, skew, kurt
# Out:
# (array(0.3), array(0.21), array(0.87287156), array(-1.23809524))

# %%
#pdf = continious und pmf = discret
